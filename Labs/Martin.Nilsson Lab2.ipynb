# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

college = pd.read_csv("College.csv")
college2 = pd.read_csv("College.csv", index_col=0)
college3 = college.rename({"Unnamed: 0": "College"}, axis=1)
college3 = college3.set_index("College")

# %%
college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
features = ["Top10perc", "Apps", "Enroll"]
pd.plotting.scatter_matrix(college[features]);

# %%
sns.boxplot(x="Private", y="Outstate",data=college)
plt.show()

# %%
college["Elite"] = pd.cut(college["Top10perc"], [0 ,50 ,100],labels=["No", "Yes"])
sns.boxplot(x="Elite",   y="Outstate", data=college, order=["Yes","No"])
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 5))
college[college["Private"] == "Yes"]["Outstate"].plot.hist(bins = 20, ax=axes[0], color="skyblue", edgecolor="white")
axes[0].set_title("Private collages - Outstate tuition")

college[college["Private"] == "No"]["Outstate"].plot.hist(bins = 20, ax=axes[1], color="salmon", edgecolor="white")
axes[1].set_title("Public collages - Outstate tuition")

for ax in axes:
    ax.set_xlabel("Tuition $")
    ax.set_ylabel("Number of collages")
    ax.grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Samband mellan olika faktorer och examensgrad
#
# Nedan tog jag fram fyra histogram som jämför examensgrad "Grad.Rate" mellan olika grupper av skolor.
# Jag ville se om skoltyp, alumniengagemang, lärartäthet och resurser per student påverkar examensgraden. Logiskt redan nu bör t.ex privata skolor ha högre examensgrad, har lärarna färre studenter att ta hand om bör vi också se högre examensgrad, bara för att nämna två tidiga tankar om det hela.
#
# Så nedan ser vi jämförelser enligt detta.
# Varje subplot visar en jämförelse:
# - **Övre vänster:** Private vs Public skolor
# - **Övre höger:** Hög vs Låg andel aktiva alumner
# - **Nedre vänster:** Låg vs Hög student–faculty ratio
# - **Nedre höger:** Låga vs Höga utgifter per student

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 5))
college[college["Private"] == "Yes"]["Grad.Rate"].plot.hist(bins = 50, ax=axes[0,0], color="skyblue", edgecolor="white",label="Private", alpha=0.5)
college[college["Private"] == "No"]["Grad.Rate"].plot.hist(bins = 50, ax=axes[0,0], color="salmon", edgecolor="white",label="Public", alpha=0.5)
axes[0,0].set_title("Private/Public - Graduation rate")
axes[0,0].legend()

college["Alumni_Group"] = pd.cut(college["perc.alumni"], bins=[0,21,100], labels=["Low alumni", "High alumni"])
college[college["Alumni_Group"]=="Low alumni"]["Grad.Rate"].plot.hist(bins = 50 ,ax=axes[0,1], color="skyblue", edgecolor="white",label="Low alumni", alpha=0.5)
college[college["Alumni_Group"]=="High alumni"]["Grad.Rate"].plot.hist(bins = 50 ,ax=axes[0,1], color="salmon", edgecolor="white",label="High alumni", alpha=0.5)
axes[0,1].set_title("High/low alumni - Graduation rate")
axes[0,1].legend()


college["SFR_Group"] = pd.cut(college["S.F.Ratio"], bins=[0,13, college["S.F.Ratio"].max()], labels=["Low ratio (≤10)", "High ratio (>10)"])
college[college["SFR_Group"]=="Low ratio (≤10)"]["Grad.Rate"].plot.hist(bins = 50 ,ax=axes[1,0], color="skyblue", edgecolor="white",label="Low Ratio", alpha=0.5)
college[college["SFR_Group"]=="High ratio (>10)"]["Grad.Rate"].plot.hist(bins = 50 ,ax=axes[1,0], color="salmon", edgecolor="white",label="High Ratio", alpha=0.5)
axes[1,0].set_title("Student–Faculty Ratio – Graduation rate")
axes[1,0].legend()


college["Expend_Group"] = pd.cut(college["Expend"], bins=[0,10000, college["Expend"].max()], labels=["Low expend", "High expend"])
college[college["Expend_Group"]=="Low expend"]["Grad.Rate"].plot.hist(bins = 50 ,ax=axes[1,1], color="skyblue", edgecolor="white",label="Low expenditure", alpha=0.5)
college[college["Expend_Group"]=="High expend"]["Grad.Rate"].plot.hist(bins = 50 ,ax=axes[1,1], color="salmon", edgecolor="white",label="High expenditure",alpha=0.5)
axes[1,1].set_title("Expenditures per Student – Graduation rate")
axes[1,1].legend()

for ax in axes.flatten():
    ax.set_xlabel("Graduation Rate (%)")
    ax.set_ylabel("Number of Colleges")

fig.suptitle("Graduation Rate Distributions by Different Factors", fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tolkning
#
#
# * **Private vs Public:** Vi ser ju att privata skolor har generellt en mycket högre examensgrad, till och med över 100% i vissa fall, hur nu det går till.
#     Offentliga ligger bra mycket efter, vilket är tråkigt att se då det är många som inte har råd med privata skolor.
# * **Alumni:** Skolor med högre alumniengagemant, (över 21%), uppvisar betydligt högre examensgrad. De flesta låg-alumni-skolor har examensgrad mellan 45-70%, medan hög-alumni-skolor ligger på 65-100%.
#     Detta betyder ju då att skolor med engagerande alumner tenderar att vara mer framgångsrika i att få sina studenter att ta examen.
# * **Student–Faculty Ratio:** Skolor med lägre ratio (≤14 studenter per lärare) är bra många färre, men har ändå en liten trend till högre examensgrad. De flesta skolor har högre ratio (>14), och bland dessa ligger examensgraden vanligtvis mellan 35–65 %.
#     Resultatet tyder på att lägre ratio kan bidra till bättre studentresultat,
# * **Expenditures:** Skolor med högre utgifter per student (>10 000 $) uppvisar generellt högre examensgrader, oftast i intervallet 65-100 %.
#     Skolor med lägre utgifter (<10 000 $) ligger däremot i intervallet 50–70 %, och färre når de högre nivåerna. Det tyder på att större resurser inte alls garanterar framgång, men de verkar minska risken för låga resultat och öka sannolikheten för att fler studenter tar examen.
#
#
# ### Sammanfattning
#
# Vi se genom analyserna att flera faktorer verkar påverka hur väl skolor lyckas med sina studenter.
# Privata skolor och de med högre alumniengagemang tenderar att ha betydligt högre examensgrad än offentliga skolor.
# Lärartäthet (student–faculty ratio) verkar också spela roll – skolor med färre studenter per lärare presterar i genomsnitt bättre.
# Även skolor som spenderar mer resurser per student har en tydligare koncentration mot högre examensgrader.
# Ingen enskild faktor garanterar framgång, men resultaten antyder att resurser, engagemang och lärartillgång tillsammans
# har en stark koppling till bättre studieresultat.
